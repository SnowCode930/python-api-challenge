# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import os
from pathlib import Path
import matplotlib.pyplot as plt


# Import API key
from api_keys import geoapify_key

# %%
# No warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
input_path = os.path.join("..","output_data","cities.csv")
city_data_df = pd.read_csv(input_path)
city_data_df = pd.DataFrame(city_data_df)
# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
map_plot_1=city_data_df.hvplot.points(
    "Long",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    color="City",
    alpha=.70)

# Display the map
map_plot_1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\util.py:230, in process_crs(crs)
#     229 try:
# --> 230     import cartopy.crs as ccrs
#     231     import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\Computer\Desktop\NorthWestern Homework File\Challenge 6\python-api-challenge\Instructions\Starter_Code\starter_code\VacationPy.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> map_plot_1=city_data_df.hvplot.points(
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a>     "Long",
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a>     "Lat",
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a>     geo=True,
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     tiles="OSM",
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     frame_width=700,
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     frame_height=500,
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=7'>8</a>     color="City",
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     alpha=.70)
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=10'>11</a> # Display the map
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#W4sZmlsZQ%3D%3D?line=11'>12</a> map_plot_1
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\plotting\core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\plotting\core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\util.py:234, in process_crs(crs)
#     232     import pyproj
#     233 except ImportError:
# --> 234     raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     236 if crs is None:
#     237     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

ideal_cities_df = city_data_df.loc[(city_data_df["Lat"] > 0) & (city_data_df["Max Temp"] > 20) & (city_data_df["Max Temp"])]

# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna(how='any')

# Display sample data
ideal_cities_df.head(30)
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0          0                faya  18.3851   42.4509     22.06        35
# 29        29         saint-louis  16.3333  -15.0000     38.80        24
# 39        39            tomatlan  19.9333 -105.2500     28.05        71
# 45        45               kapaa  22.0752 -159.3190     22.99        84
# 46        46           mogadishu   2.0371   45.3438     25.67        83
# 51        51                hilo  19.7297 -155.0900     26.27        83
# 52        52             businga   3.3333   20.8833     24.82        87
# 53        53                lasa  46.6166   10.7002     23.49        68
# 55        55             cayenne   4.9333  -52.3333     32.02        58
# 63        63               banda  25.4833   80.3333     24.62        52
# 73        73               nalut  30.3333   10.8500     25.41        27
# 81        81       makakilo city  21.3469 -158.0858     21.66        81
# 84        84              darnah  32.7670   22.6367     20.86        73
# 88        88        ponta do sol  32.6667  -17.1000     26.51        69
# 93        93           ugoofaaru   5.6667   73.0000     26.95        80
# 94        94          butaritari   3.0707  172.7902     27.47        77
# 95        95           kavaratti  10.5669   72.6420     27.12        78
# 99        99         trincomalee   8.5711   81.2335     26.66        82
# 106      106            palencia  42.4167   -4.5000     24.40        30
# 110      110            calabozo   8.9242  -67.4293     28.66        75
# 111      111          sao filipe  14.8961  -24.4956     26.87        78
# 116      116            victoria  22.2855  114.1577     20.14        77
# 129      129    bocana de paiwas  12.7857  -85.1227     26.99        81
# 138      138                ocos  14.5094  -92.1933     26.56        86
# 139      139          georgetown   5.4112  100.3354     28.86        89
# 142      142             peniche  39.3558   -9.3811     22.82        89
# 146      146  puerto del rosario  28.5004  -13.8627     24.86        73
# 152      152             kahului  20.8947 -156.4700     23.80        60
# 154      154              sabang   5.8933   95.3214     27.00        81
# 156      156         corn island  12.1694  -83.0418     28.07        74
#
#      Cloudiness  Wind Speed Country        Date
# 0            21        2.60      SA  1666108228
# 29            4        1.78      SN  1666108247
# 39           93        0.58      MX  1666108255
# 45            0        3.60      US  1666108257
# 46           13        6.45      SO  1666108258
# 51            0        2.57      US  1666108260
# 52           99        0.97      CD  1666108261
# 53           11        2.01      IT  1666108019
# 55           75        5.14      GF  1666108014
# 63            0        2.68      IN  1666108268
# 73            0        5.11      LY  1666108275
# 81            0        2.57      US  1666108282
# 84           50        7.20      LY  1666108283
# 88           69        3.91      PT  1666108284
# 93          100        8.28      MV  1666108290
# 94          100        6.02      KI  1666108291
# 95          100        7.00      IN  1666108292
# 99          100        6.96      LK  1666108294
# 106          40        8.66      ES  1666108219
# 110          80        2.61      VE  1666108301
# 111          46        3.71      CV  1666108301
# 116         100        6.71      HK  1666108269
# 129          99        1.83      NI  1666108313
# 138         100        5.18      GT  1666108317
# 139          40        1.54      MY  1666108133
# 142          84        8.69      PT  1666108321
# 146           0        4.63      ES  1666108035
# 152           0        3.09      US  1666108246
# 154          99        9.99      ID  1666108330
# 156          85        3.44      NI  1666108331

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#            City Country      Lat       Lng  Humidity Hotel Name
# 0          faya      SA  18.3851   42.4509        35
# 29  saint-louis      SN  16.3333  -15.0000        24
# 39     tomatlan      MX  19.9333 -105.2500        71
# 45        kapaa      US  22.0752 -159.3190        84
# 46    mogadishu      SO   2.0371   45.3438        83

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 5000
params = {
    "categories": "accommodation",
    "apiKey": geoapify_key,
    "limit":20
}


# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{radius}@{longitude},{latitude}"
    params["bias"] = f"proximity:{radius}@{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# faya - nearest hotel: No hotel found
# saint-louis - nearest hotel: No hotel found
# tomatlan - nearest hotel: No hotel found
# kapaa - nearest hotel: No hotel found
# mogadishu - nearest hotel: No hotel found
# hilo - nearest hotel: No hotel found
# businga - nearest hotel: No hotel found
# lasa - nearest hotel: No hotel found
# cayenne - nearest hotel: No hotel found
# banda - nearest hotel: No hotel found
# nalut - nearest hotel: No hotel found
# makakilo city - nearest hotel: No hotel found
# darnah - nearest hotel: No hotel found
# ponta do sol - nearest hotel: No hotel found
# ugoofaaru - nearest hotel: No hotel found
# butaritari - nearest hotel: No hotel found
# kavaratti - nearest hotel: No hotel found
# trincomalee - nearest hotel: No hotel found
# palencia - nearest hotel: No hotel found
# calabozo - nearest hotel: No hotel found
# sao filipe - nearest hotel: No hotel found
# victoria - nearest hotel: No hotel found
# bocana de paiwas - nearest hotel: No hotel found
# ocos - nearest hotel: No hotel found
# georgetown - nearest hotel: No hotel found
# peniche - nearest hotel: No hotel found
# puerto del rosario - nearest hotel: No hotel found
# kahului - nearest hotel: No hotel found
# sabang - nearest hotel: No hotel found
# corn island - nearest hotel: No hotel found
# sur - nearest hotel: No hotel found
# chunhuhub - nearest hotel: No hotel found
# ouallam - nearest hotel: No hotel found
# freetown - nearest hotel: No hotel found
# sembakung - nearest hotel: No hotel found
# cacahuatepec - nearest hotel: No hotel found
# bumba - nearest hotel: No hotel found
# cabra - nearest hotel: No hotel found
# gat - nearest hotel: No hotel found
# meulaboh - nearest hotel: No hotel found
# laguna - nearest hotel: No hotel found
# sao teotonio - nearest hotel: No hotel found
# puri - nearest hotel: No hotel found
# yumbe - nearest hotel: No hotel found
# san cristobal - nearest hotel: No hotel found
# makokou - nearest hotel: No hotel found
# tikaitnagar - nearest hotel: No hotel found
# sembe - nearest hotel: No hotel found
# high rock - nearest hotel: No hotel found
# balabac - nearest hotel: No hotel found
# bintulu - nearest hotel: No hotel found
# tchaourou - nearest hotel: No hotel found
# pathanamthitta - nearest hotel: No hotel found
# camacha - nearest hotel: No hotel found
# hambantota - nearest hotel: No hotel found
# san quintin - nearest hotel: No hotel found
# samana - nearest hotel: No hotel found
# cockburn town - nearest hotel: No hotel found
# tura - nearest hotel: No hotel found
# sakakah - nearest hotel: No hotel found
# kloulklubed - nearest hotel: No hotel found
# praia - nearest hotel: No hotel found
# okitipupa - nearest hotel: No hotel found
# san andres - nearest hotel: No hotel found
# dunmore town - nearest hotel: No hotel found
# camopi - nearest hotel: No hotel found
# jalu - nearest hotel: No hotel found
# eyl - nearest hotel: No hotel found
# kingman - nearest hotel: No hotel found
# la romana - nearest hotel: No hotel found
# bucerias - nearest hotel: No hotel found
# bathsheba - nearest hotel: No hotel found
# salalah - nearest hotel: No hotel found
# yarada - nearest hotel: No hotel found
# viseu - nearest hotel: No hotel found
# bafoulabe - nearest hotel: No hotel found
# kailua - nearest hotel: No hotel found
# santa rosalia - nearest hotel: No hotel found
# mana - nearest hotel: No hotel found
# mandera - nearest hotel: No hotel found
# numan - nearest hotel: No hotel found
# narwar - nearest hotel: No hotel found
# tabou - nearest hotel: No hotel found
# dicabisagan - nearest hotel: No hotel found
# adrar - nearest hotel: No hotel found
# port blair - nearest hotel: No hotel found
# buraydah - nearest hotel: No hotel found
# saint-francois - nearest hotel: No hotel found
# bogande - nearest hotel: No hotel found
# acajutla - nearest hotel: No hotel found
# capoterra - nearest hotel: No hotel found
# muisne - nearest hotel: No hotel found
# tagusao - nearest hotel: No hotel found
# mao - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: No hotel found
# panuco - nearest hotel: No hotel found
# stolac - nearest hotel: No hotel found
# port-de-bouc - nearest hotel: No hotel found
# pachino - nearest hotel: No hotel found
# lakki marwat - nearest hotel: No hotel found
# thinadhoo - nearest hotel: No hotel found
# colares - nearest hotel: No hotel found
# samandag - nearest hotel: No hotel found
# san joaquin - nearest hotel: No hotel found
# tessalit - nearest hotel: No hotel found
# yaan - nearest hotel: No hotel found
# ixtapa - nearest hotel: No hotel found
# dong hoi - nearest hotel: No hotel found
# harindanga - nearest hotel: No hotel found
# the valley - nearest hotel: No hotel found
# araouane - nearest hotel: No hotel found
# singkang - nearest hotel: No hotel found
# taitung - nearest hotel: No hotel found
# praya - nearest hotel: No hotel found
# abu zabad - nearest hotel: No hotel found
# beaune - nearest hotel: No hotel found
# brokopondo - nearest hotel: No hotel found
# tikrit - nearest hotel: No hotel found
# lahij - nearest hotel: No hotel found
# kapit - nearest hotel: No hotel found
# bhandara - nearest hotel: No hotel found
# sawakin - nearest hotel: No hotel found
# rameswaram - nearest hotel: No hotel found
# guerrero negro - nearest hotel: No hotel found
# bandarbeyla - nearest hotel: No hotel found
# bauta - nearest hotel: No hotel found
# todos santos - nearest hotel: No hotel found
# yaring - nearest hotel: No hotel found
# isiro - nearest hotel: No hotel found
# nicoya - nearest hotel: No hotel found
# nouadhibou - nearest hotel: No hotel found
# bilma - nearest hotel: No hotel found
# vung tau - nearest hotel: No hotel found
# juba - nearest hotel: No hotel found
# pali - nearest hotel: No hotel found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Computer\Desktop\NorthWestern Homework File\Challenge 6\python-api-challenge\Instructions\Starter_Code\starter_code\VacationPy.ipynb Cell 12 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a> base_url = "https://api.geoapify.com/v2/places"
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a> # Make and API request using the params dictionaty
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X13sZmlsZQ%3D%3D?line=27'>28</a> name_address = requests.get(base_url, params=params)
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X13sZmlsZQ%3D%3D?line=29'>30</a> # Convert the API response to JSON format
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X13sZmlsZQ%3D%3D?line=30'>31</a> name_address = name_address.json()
#
# File c:\Users\Computer\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\Computer\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\Computer\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\Computer\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\Computer\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File c:\Users\Computer\anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File c:\Users\Computer\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File c:\Users\Computer\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles='OSM',
    frame_width = 700,
    frame_height = 500, 
    color='City',
    hover_cols=["Hotel Name","Country"]
    )

# Display the map
map_plot_2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\util.py:230, in process_crs(crs)
#     229 try:
# --> 230     import cartopy.crs as ccrs
#     231     import geoviews as gv # noqa
#
# ModuleNotFoundError: No module named 'cartopy'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\Computer\Desktop\NorthWestern Homework File\Challenge 6\python-api-challenge\Instructions\Starter_Code\starter_code\VacationPy.ipynb Cell 14 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> # Configure the map plot
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> map_plot_2 = hotel_df.hvplot.points(
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     "Lng",
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     "Lat",
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     geo=True,
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     tiles='OSM',
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     frame_width = 700,
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>     frame_height = 500,
#       <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>     color='City',
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>     hover_cols=["Hotel Name","Country"]
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> # Display the map
#      <a href='vscode-notebook-cell:/c%3A/Users/Computer/Desktop/NorthWestern%20Homework%20File/Challenge%206/python-api-challenge/Instructions/Starter_Code/starter_code/VacationPy.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> map_plot_2
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\plotting\core.py:1612, in hvPlotTabular.points(self, x, y, **kwds)
#    1554 def points(self, x=None, y=None, **kwds):
#    1555     """
#    1556     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1557     geographic plots.
#    (...)
#    1610     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1611     """
# -> 1612     return self(x, y, kind="points", **kwds)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\plotting\core.py:92, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      89         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      90         return pn.panel(plot, **panel_dict)
# ---> 92 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\plotting\core.py:99, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#      97 y = y or params.pop("y", None)
#      98 kind = kind or params.pop("kind", None)
# ---> 99 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\converter.py:396, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, **kwds)
#     394 self.dynamic = dynamic
#     395 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 396 self.crs = self._process_crs(data, crs) if self.geo else None
#     397 self.project = project
#     398 self.coastline = coastline
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\converter.py:650, in HoloViewsConverter._process_crs(self, data, crs)
#     647     _crs = getattr(data, 'attrs', {}).get(crs or 'crs', crs)
#     649 try:
# --> 650     return process_crs(_crs)
#     651 except ValueError:
#     652     # only raise error if crs was specified in kwargs
#     653     if crs:
#
# File c:\Users\Computer\anaconda3\lib\site-packages\hvplot\util.py:234, in process_crs(crs)
#     232     import pyproj
#     233 except ImportError:
# --> 234     raise ImportError('Geographic projection support requires GeoViews, pyproj and cartopy.')
#     236 if crs is None:
#     237     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires GeoViews, pyproj and cartopy.
